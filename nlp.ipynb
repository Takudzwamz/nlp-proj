# %%
import requests

def search_wikidata(term):
    base_url = "https://www.wikidata.org/w/api.php"
    params = {
        "action": "wbsearchentities",
        "language": "en",
        "format": "json",
        "search": term
    }
    response = requests.get(base_url, params=params)
    return response.json()

# Example usage
search_results = search_wikidata("Victoria Falls")
print(search_results)
# Out:
# {'searchinfo': {'search': 'Victoria Falls'}, 'search': [{'id': 'Q43278', 'title': 'Q43278', 'pageid': 45475, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}, 'description': {'value': 'waterfall on the Zambezi River in Zambia and Zimbabwe', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q43278', 'concepturi': 'http://www.wikidata.org/entity/Q43278', 'label': 'Victoria Falls', 'description': 'waterfall on the Zambezi River in Zambia and Zimbabwe', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q1393804', 'title': 'Q1393804', 'pageid': 1332889, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}, 'description': {'value': 'town in the province of Matabeleland North, Zimbabwe', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q1393804', 'concepturi': 'http://www.wikidata.org/entity/Q1393804', 'label': 'Victoria Falls', 'description': 'town in the province of Matabeleland North, Zimbabwe', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q7926699', 'title': 'Q7926699', 'pageid': 7865990, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}, 'description': {'value': 'waterfall in Wester Ross, Highland, Scotland, UK', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q7926699', 'concepturi': 'http://www.wikidata.org/entity/Q7926699', 'label': 'Victoria Falls', 'description': 'waterfall in Wester Ross, Highland, Scotland, UK', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q100180698', 'title': 'Q100180698', 'pageid': 97904079, 'display': {'label': {'value': 'The Victoria Falls', 'language': 'en'}, 'description': {'value': 'book by Emil Holub', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q100180698', 'concepturi': 'http://www.wikidata.org/entity/Q100180698', 'label': 'The Victoria Falls', 'description': 'book by Emil Holub', 'match': {'type': 'alias', 'language': 'en', 'text': 'Victoria Falls'}, 'aliases': ['Victoria Falls']}, {'id': 'Q32039611', 'title': 'Q32039611', 'pageid': 33514813, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q32039611', 'concepturi': 'http://www.wikidata.org/entity/Q32039611', 'label': 'Victoria Falls', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q61278383', 'title': 'Q61278383', 'pageid': 61130624, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}, 'description': {'value': 'waterfall in St Patrick Parish, Dominica', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q61278383', 'concepturi': 'http://www.wikidata.org/entity/Q61278383', 'label': 'Victoria Falls', 'description': 'waterfall in St Patrick Parish, Dominica', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q67354989', 'title': 'Q67354989', 'pageid': 66950765, 'display': {'label': {'value': 'Victoria falls', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q67354989', 'concepturi': 'http://www.wikidata.org/entity/Q67354989', 'label': 'Victoria falls', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria falls'}}], 'search-continue': 7, 'success': 1}

# %%
def extract_entities(api_response):
    entities = []
    for item in api_response['search']:
        entity = {
            'id': item['id'],
            'label': item['label'],
            'description': item['description'],
            'url': f"https://www.wikidata.org/wiki/{item['id']}"
        }
        entities.append(entity)
    return entities

# Use the function on the API response you received
extracted_entities = extract_entities(search_results)
print(extracted_entities)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 14
#      11     return entities
#      13 # Use the function on the API response you received
# ---> 14 extracted_entities = extract_entities(search_results)
#      15 print(extracted_entities)
#
# Cell In[24], line 7, in extract_entities(api_response)
#       2 entities = []
#       3 for item in api_response['search']:
#       4     entity = {
#       5         'id': item['id'],
#       6         'label': item['label'],
# ----> 7         'description': item['description'],
#       8         'url': f"https://www.wikidata.org/wiki/{item['id']}"
#       9     }
#      10     entities.append(entity)
#      11 return entities
#
# KeyError: 'description'

# %% [markdown]
# #### Load the Pre-trained Model and Tokenizer: We'll load DistilBERT and its tokenizer.

# %%
import torch
from transformers import DistilBertTokenizer, DistilBertModel

# Load pre-trained model and tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertModel.from_pretrained('distilbert-base-uncased')

def get_sentence_embedding(sentence):
    # Tokenize the input sentence and convert to tensor
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True)
    
    # Get embeddings from the model
    with torch.no_grad():
        outputs = model(**inputs)
        # Use the pooled output for sentence-level embeddings
        embeddings = outputs.last_hidden_state.mean(dim=1)
    return embeddings

# Example usage
sentence = "Victoria Falls is one of the seven wonders of the world"
embedding = get_sentence_embedding(sentence)
print(embedding)
# Out:
# tensor([[-4.2955e-01,  9.1230e-02,  2.2616e-01,  2.9911e-02,  3.1104e-01,
#          -6.6161e-03,  6.3255e-01,  7.9957e-01, -4.8268e-01, -1.6842e-01,
#           1.2238e-01, -7.3071e-01, -1.1764e-01,  9.0988e-01, -2.2506e-01,
#           1.1047e-01,  2.9680e-02,  7.9962e-02,  2.1271e-01,  2.1784e-01,
#          -6.1431e-02, -2.8651e-01,  2.1794e-03,  2.5708e-01,  3.3211e-01,
#           1.0114e-01, -2.0919e-01,  1.0943e-01,  3.4491e-02, -1.2300e-01,
#           7.5801e-02,  8.5728e-02, -3.0309e-01, -2.1564e-01, -1.0767e-01,
#          -1.1439e-01, -4.9221e-03, -4.0638e-01, -3.4736e-01,  3.8438e-01,
#          -6.4663e-01, -4.6051e-01,  2.5702e-01, -6.5436e-02, -1.0081e-01,
#          -1.2579e-01,  7.8719e-02, -2.2484e-01,  1.8120e-01, -1.3343e-01,
#          -2.4357e-01,  3.4546e-01, -1.5124e-01,  1.2019e-01,  1.8515e-01,
#           5.2130e-01, -1.8632e-01,  1.1250e-01, -5.1981e-01, -8.0578e-02,
#          -3.1802e-02,  1.0935e-01, -9.7734e-02, -4.0052e-01, -1.9681e-01,
#           1.0941e-01,  1.3305e-01,  4.0690e-01, -5.3192e-02, -9.0899e-02,
#          -8.6872e-03, -3.0604e-01,  3.1366e-01, -1.1234e-01, -4.9866e-01,
#          -1.1942e-01, -4.0880e-01,  2.1071e-01, -4.6437e-02, -3.2654e-01,
#          -8.8949e-02,  7.3275e-01,  7.9909e-02,  4.5194e-01, -7.9782e-03,
#           1.9703e-01, -5.4944e-01, -1.5891e-01, -3.9171e-01,  4.8347e-01,
#          -4.1857e-01, -7.9885e-02,  2.8848e-01,  2.5275e-02,  4.6241e-01,
#          -1.0431e+00,  5.6255e-02, -7.9390e-02, -2.1024e-01,  3.4036e-01,
#           1.7363e-01, -6.1073e-01,  7.6060e-02,  2.7710e-01,  5.7980e-02,
#          -1.8934e-01,  2.5287e-01,  1.9375e-01,  3.2449e-01,  1.3163e-01,
#           1.4440e-01, -2.6712e-01, -1.0921e-01, -1.8721e-01, -1.6255e-01,
#           2.2885e-01,  2.3614e-01, -3.9620e-01,  7.0349e-02, -1.8700e-01,
#           2.8419e-01, -7.9881e-02, -1.7599e-01, -4.6990e-01, -1.9824e-01,
#          -4.4632e-01,  2.0946e-01, -2.4278e-01,  6.4569e-02, -1.0027e-01,
#          -8.3891e-02, -6.9818e-01,  1.0918e-01, -3.7362e-01,  1.9540e-01,
#          -7.3496e-02,  1.3080e-01,  1.2935e-01]])

# %%
def get_entity_embedding(text):
    # Tokenize and get embedding
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
        embeddings = outputs.last_hidden_state.mean(dim=1)
    return embeddings

# Example usage for an entity label
entity_label = "Victoria Falls"
entity_embedding = get_entity_embedding(entity_label)
print(entity_embedding)
# Out:
# tensor([[ 1.1037e-01,  2.7955e-01, -1.7265e-01,  1.2097e-01,  7.5108e-02,
#          -2.2447e-02,  5.9097e-01,  9.8301e-02, -2.3359e-01, -1.5754e-01,
#          -2.4414e-02, -3.0062e-01,  1.1841e-01,  3.1373e-01, -3.4294e-01,
#           3.1577e-03, -8.2589e-02, -8.3827e-02,  5.3908e-01, -4.4387e-02,
#          -7.8509e-02, -3.7347e-01,  1.0616e-01,  2.6537e-01,  1.2256e-01,
#           5.5676e-02, -2.7630e-02,  1.3146e-01, -8.9944e-02, -2.6673e-01,
#          -2.2254e-02, -1.1912e-01,  3.8635e-02,  1.3671e-01, -6.4841e-02,
#          -4.2411e-01,  3.8246e-02, -8.5504e-02, -3.0877e-01, -1.2501e-01,
#          -3.2923e-01, -3.7611e-01, -2.1320e-01, -2.2347e-01,  2.9087e-01,
#          -8.9807e-02, -2.0779e-01, -1.0389e-01, -2.7529e-01, -3.2148e-01,
#          -4.2356e-01,  4.4369e-01, -2.8014e-01,  2.9709e-02,  1.4740e-01,
#           2.5723e-01,  3.7854e-02,  2.7916e-02, -5.4874e-02,  4.5558e-03,
#           1.8528e-01,  1.3546e-01, -9.5570e-02, -7.9707e-02,  2.3744e-01,
#          -1.1839e-01,  3.2108e-01,  9.4891e-02, -3.9483e-01, -1.9689e-01,
#          -1.6484e-01, -5.5436e-01,  1.5534e-01,  1.9980e-01,  1.5557e-01,
#           1.0585e-01, -3.0389e-01,  3.5238e-01,  1.0095e-01, -2.0158e-01,
#           1.4104e-01,  6.6668e-01,  2.7359e-01,  3.4578e-01,  8.4414e-02,
#           1.4886e-01, -4.8430e-01,  1.0283e-01,  7.1056e-02, -1.5764e-02,
#          -5.7996e-01, -2.9625e-01,  8.8672e-02,  4.3097e-02,  1.7944e-01,
#          -3.6463e-01, -3.0841e-01,  1.4666e-01,  1.2093e-01,  1.4665e-01,
#           8.1092e-02, -5.0019e-01, -1.8550e-02,  3.9395e-01, -1.2952e-01,
#          -9.6143e-02,  2.3706e-02,  2.1744e-01, -6.4133e-03, -5.7095e-01,
#           2.2815e-01, -1.5002e-01,  1.1772e-01, -4.6961e-01, -3.1769e-01,
#          -1.9167e-01,  3.3527e-01, -5.7362e-02,  8.4956e-02,  4.2018e-02,
#           1.2950e-01, -7.7334e-02,  1.1184e-01,  5.9898e-01, -1.6964e-01,
#          -2.0770e-01,  1.9471e-01, -1.1237e-01,  1.4616e-01,  1.4460e-01,
#          -1.9615e-01, -5.7294e-01,  2.6258e-01, -2.1248e-01,  6.1903e-03,
#          -4.6635e-02, -2.6411e-01,  1.9660e-01]])

# %%
from torch.nn.functional import cosine_similarity

# Assuming 'embedding' is the sentence embedding and 'entity_embedding' is obtained for an entity
similarity = cosine_similarity(embedding, entity_embedding)
print(similarity)
# Out:
# tensor([0.6224])

# %%
from torch.nn.functional import cosine_similarity

def find_best_entity_match(sentence, entities):
    sentence_embedding = get_sentence_embedding(sentence)
    best_entity = None
    highest_similarity = -1  # Start with the lowest possible similarity

    for entity in entities:
        entity_label = entity['label']
        entity_embedding = get_entity_embedding(entity_label)
        
        # Calculate similarity
        similarity = cosine_similarity(sentence_embedding, entity_embedding).item()  # Convert tensor to a Python float
        print(f"Similarity with {entity_label}: {similarity}")  # Optional: print similarity for each entity

        if similarity > highest_similarity:
            highest_similarity = similarity
            best_entity = entity

    return best_entity, highest_similarity

# Example usage
sentence = "Liverpool won the match today."
best_match, similarity_score = find_best_entity_match(sentence, extracted_entities)
print(f"Best Match: {best_match}, Similarity Score: {similarity_score}")
# Out:
# Similarity with Liverpool: 0.3676189184188843
# Similarity with Liverpool F.C.: 0.527188777923584
# Similarity with Liverpool: 0.3676189184188843
# Similarity with Liverpool: 0.3676189184188843
# Similarity with Liverpool: 0.3676189184188843
# Similarity with Liverpool: 0.3676189184188843
# Similarity with Liverpool: 0.3676189184188843
# Best Match: {'id': 'Q1130849', 'label': 'Liverpool F.C.', 'description': 'Association football club in Liverpool, England', 'url': 'https://www.wikidata.org/wiki/Q1130849'}, Similarity Score: 0.527188777923584

# %%
import spacy

# Load spaCy's pre-trained English model
nlp = spacy.load("en_core_web_sm")

def extract_key_terms(sentence):
    doc = nlp(sentence)
    return [ent.text for ent in doc.ents]

# Example usage
sentence = "Victoria Falls is a waterfall in southern Africa on the Zambezi River at the border between Zambia and Zimbabwe."
key_terms = extract_key_terms(sentence)
print(key_terms)  # Should print entities like 'Eiffel Tower' and 'Paris'
# Out:
# ['Victoria Falls', 'Africa', 'the Zambezi River', 'Zambia', 'Zimbabwe']

# %%
def search_wikidata(term):
    base_url = "https://www.wikidata.org/w/api.php"
    params = {
        "action": "wbsearchentities",
        "language": "en",
        "format": "json",
        "search": term
    }
    response = requests.get(base_url, params=params)
    return response.json()

# Example usage for each key term
for term in key_terms:
    wikidata_results = search_wikidata(term)
    print(f"Results for {term}: {wikidata_results}")
# Out:
# Results for Victoria Falls: {'searchinfo': {'search': 'Victoria Falls'}, 'search': [{'id': 'Q43278', 'title': 'Q43278', 'pageid': 45475, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}, 'description': {'value': 'waterfall on the Zambezi River in Zambia and Zimbabwe', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q43278', 'concepturi': 'http://www.wikidata.org/entity/Q43278', 'label': 'Victoria Falls', 'description': 'waterfall on the Zambezi River in Zambia and Zimbabwe', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q1393804', 'title': 'Q1393804', 'pageid': 1332889, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}, 'description': {'value': 'town in the province of Matabeleland North, Zimbabwe', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q1393804', 'concepturi': 'http://www.wikidata.org/entity/Q1393804', 'label': 'Victoria Falls', 'description': 'town in the province of Matabeleland North, Zimbabwe', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q7926699', 'title': 'Q7926699', 'pageid': 7865990, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}, 'description': {'value': 'waterfall in Wester Ross, Highland, Scotland, UK', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q7926699', 'concepturi': 'http://www.wikidata.org/entity/Q7926699', 'label': 'Victoria Falls', 'description': 'waterfall in Wester Ross, Highland, Scotland, UK', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q100180698', 'title': 'Q100180698', 'pageid': 97904079, 'display': {'label': {'value': 'The Victoria Falls', 'language': 'en'}, 'description': {'value': 'book by Emil Holub', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q100180698', 'concepturi': 'http://www.wikidata.org/entity/Q100180698', 'label': 'The Victoria Falls', 'description': 'book by Emil Holub', 'match': {'type': 'alias', 'language': 'en', 'text': 'Victoria Falls'}, 'aliases': ['Victoria Falls']}, {'id': 'Q32039611', 'title': 'Q32039611', 'pageid': 33514813, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q32039611', 'concepturi': 'http://www.wikidata.org/entity/Q32039611', 'label': 'Victoria Falls', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q61278383', 'title': 'Q61278383', 'pageid': 61130624, 'display': {'label': {'value': 'Victoria Falls', 'language': 'en'}, 'description': {'value': 'waterfall in St Patrick Parish, Dominica', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q61278383', 'concepturi': 'http://www.wikidata.org/entity/Q61278383', 'label': 'Victoria Falls', 'description': 'waterfall in St Patrick Parish, Dominica', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria Falls'}}, {'id': 'Q67354989', 'title': 'Q67354989', 'pageid': 66950765, 'display': {'label': {'value': 'Victoria falls', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q67354989', 'concepturi': 'http://www.wikidata.org/entity/Q67354989', 'label': 'Victoria falls', 'match': {'type': 'label', 'language': 'en', 'text': 'Victoria falls'}}], 'search-continue': 7, 'success': 1}
# Results for Africa: {'searchinfo': {'search': 'Africa'}, 'search': [{'id': 'Q15', 'title': 'Q15', 'pageid': 111, 'display': {'label': {'value': 'Africa', 'language': 'en'}, 'description': {'value': 'continent', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q15', 'concepturi': 'http://www.wikidata.org/entity/Q15', 'label': 'Africa', 'description': 'continent', 'match': {'type': 'label', 'language': 'en', 'text': 'Africa'}}, {'id': 'Q181238', 'title': 'Q181238', 'pageid': 180419, 'display': {'label': {'value': 'Africa', 'language': 'en'}, 'description': {'value': 'Roman province on the northern African coast covering parts of present-day Tunisia, Algeria, and Libya', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q181238', 'concepturi': 'http://www.wikidata.org/entity/Q181238', 'label': 'Africa', 'description': 'Roman province on the northern African coast covering parts of present-day Tunisia, Algeria, and Libya', 'match': {'type': 'label', 'language': 'en', 'text': 'Africa'}}, {'id': 'Q4689536', 'title': 'Q4689536', 'pageid': 4480902, 'display': {'label': {'value': 'Africa', 'language': 'en'}, 'description': {'value': 'African studies academic journal', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q4689536', 'concepturi': 'http://www.wikidata.org/entity/Q4689536', 'label': 'Africa', 'description': 'African studies academic journal', 'match': {'type': 'label', 'language': 'en', 'text': 'Africa'}}, {'id': 'Q136898', 'title': 'Q136898', 'pageid': 138642, 'display': {'label': {'value': '1193 Africa', 'language': 'en'}, 'description': {'value': 'asteroid', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q136898', 'concepturi': 'http://www.wikidata.org/entity/Q136898', 'label': '1193 Africa', 'description': 'asteroid', 'match': {'type': 'alias', 'language': 'en', 'text': 'Africa'}, 'aliases': ['Africa']}, {'id': 'Q410453', 'title': 'Q410453', 'pageid': 388897, 'display': {'label': {'value': 'Ethiopia', 'language': 'en'}, 'description': {'value': 'A historical term for all or most of sub-Saharan Africa or Black Africa, inclusive of much more than modern Ethiopia but almost never Egypt, Tunisia, or the land of the Berbers; in Greco-Roman mythology, considered devout and close to the gods', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q410453', 'concepturi': 'http://www.wikidata.org/entity/Q410453', 'label': 'Ethiopia', 'description': 'A historical term for all or most of sub-Saharan Africa or Black Africa, inclusive of much more than modern Ethiopia but almost never Egypt, Tunisia, or the land of the Berbers; in Greco-Roman mythology, considered devout and close to the gods', 'match': {'type': 'alias', 'language': 'en', 'text': 'Africa'}, 'aliases': ['Africa']}, {'id': 'Q383842', 'title': 'Q383842', 'pageid': 365202, 'display': {'label': {'value': 'Africa', 'language': 'en'}, 'description': {'value': 'song written and composed by David Paich and Jeff Porcaro, originally recorded by Toto in 1981 and released in 1982', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q383842', 'concepturi': 'http://www.wikidata.org/entity/Q383842', 'label': 'Africa', 'description': 'song written and composed by David Paich and Jeff Porcaro, originally recorded by Toto in 1981 and released in 1982', 'match': {'type': 'label', 'language': 'en', 'text': 'Africa'}}, {'id': 'Q6172568', 'title': 'Q6172568', 'pageid': 5968456, 'display': {'label': {'value': 'Africa', 'language': 'en'}, 'description': {'value': 'female given name', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q6172568', 'concepturi': 'http://www.wikidata.org/entity/Q6172568', 'label': 'Africa', 'description': 'female given name', 'match': {'type': 'label', 'language': 'en', 'text': 'Africa'}}], 'search-continue': 7, 'success': 1}
# Results for the Zambezi River: {'searchinfo': {'search': 'the Zambezi River'}, 'search': [{'id': 'Q57530850', 'title': 'Q57530850', 'pageid': 57447103, 'display': {'label': {'value': 'The Zambezi River: tectonism, climatic change and drainage evolution — is there really evidence for a catastrophic flood? A discussion', 'language': 'en'}, 'description': {'value': 'article', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q57530850', 'concepturi': 'http://www.wikidata.org/entity/Q57530850', 'label': 'The Zambezi River: tectonism, climatic change and drainage evolution — is there really evidence for a catastrophic flood? A discussion', 'description': 'article', 'match': {'type': 'label', 'language': 'en', 'text': 'The Zambezi River: tectonism, climatic change and drainage evolution — is there really evidence for a catastrophic flood? A discussion'}}], 'success': 1}
# Results for Zambia: {'searchinfo': {'search': 'Zambia'}, 'search': [{'id': 'Q953', 'title': 'Q953', 'pageid': 1280, 'display': {'label': {'value': 'Zambia', 'language': 'en'}, 'description': {'value': 'country at the crossroads of Central and Southern Africa', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q953', 'concepturi': 'http://www.wikidata.org/entity/Q953', 'label': 'Zambia', 'description': 'country at the crossroads of Central and Southern Africa', 'match': {'type': 'label', 'language': 'en', 'text': 'Zambia'}}, {'id': 'Q114513696', 'title': 'Q114513696', 'pageid': 109203071, 'display': {'label': {'value': 'Zambia', 'language': 'en'}, 'description': {'value': 'episode of Man vs. Wild (S2 E8)', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q114513696', 'concepturi': 'http://www.wikidata.org/entity/Q114513696', 'label': 'Zambia', 'description': 'episode of Man vs. Wild (S2 E8)', 'match': {'type': 'label', 'language': 'en', 'text': 'Zambia'}}, {'id': 'Q5564383', 'title': 'Q5564383', 'pageid': 5324772, 'display': {'label': {'value': 'Girl Guides Association of Zambia', 'language': 'en'}, 'description': {'value': 'organization', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q5564383', 'concepturi': 'http://www.wikidata.org/entity/Q5564383', 'label': 'Girl Guides Association of Zambia', 'description': 'organization', 'match': {'type': 'alias', 'language': 'en', 'text': 'Zambia'}, 'aliases': ['Zambia']}, {'id': 'Q103922476', 'title': 'Q103922476', 'pageid': 99427489, 'display': {'label': {'value': 'Zambia', 'language': 'en'}, 'description': {'value': 'shipwreck off the Scottish Coast', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q103922476', 'concepturi': 'http://www.wikidata.org/entity/Q103922476', 'label': 'Zambia', 'description': 'shipwreck off the Scottish Coast', 'match': {'type': 'label', 'language': 'en', 'text': 'Zambia'}}, {'id': 'Q206350', 'title': 'Q206350', 'pageid': 202619, 'display': {'label': {'value': 'Zambia national football team', 'language': 'en'}, 'description': {'value': 'national association football team', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q206350', 'concepturi': 'http://www.wikidata.org/entity/Q206350', 'label': 'Zambia national football team', 'description': 'national association football team', 'match': {'type': 'label', 'language': 'en', 'text': 'Zambia national football team'}}, {'id': 'Q19428934', 'title': 'Q19428934', 'pageid': 21035459, 'display': {'label': {'value': '2011 Zambian general election', 'language': 'en'}, 'description': {'value': '1st Elected to parliament in September 2011', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q19428934', 'concepturi': 'http://www.wikidata.org/entity/Q19428934', 'label': '2011 Zambian general election', 'description': '1st Elected to parliament in September 2011', 'match': {'type': 'alias', 'language': 'en', 'text': 'Zambian general election, 2011'}, 'aliases': ['Zambian general election, 2011']}, {'id': 'Q73408', 'title': 'Q73408', 'pageid': 76093, 'display': {'label': {'value': 'Zambian Kwacha', 'language': 'en'}, 'description': {'value': 'official currency of Zambia', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q73408', 'concepturi': 'http://www.wikidata.org/entity/Q73408', 'label': 'Zambian Kwacha', 'description': 'official currency of Zambia', 'match': {'type': 'label', 'language': 'en', 'text': 'Zambian Kwacha'}}], 'search-continue': 7, 'success': 1}
# Results for Zimbabwe: {'searchinfo': {'search': 'Zimbabwe'}, 'search': [{'id': 'Q954', 'title': 'Q954', 'pageid': 1281, 'display': {'label': {'value': 'Zimbabwe', 'language': 'en'}, 'description': {'value': 'sovereign state in southern Africa', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q954', 'concepturi': 'http://www.wikidata.org/entity/Q954', 'label': 'Zimbabwe', 'description': 'sovereign state in southern Africa', 'match': {'type': 'label', 'language': 'en', 'text': 'Zimbabwe'}}, {'id': 'Q16968451', 'title': 'Q16968451', 'pageid': 18572233, 'display': {'label': {'value': 'Zimbabwe', 'language': 'en'}, 'description': {'value': '2007 live album by Dispatch', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q16968451', 'concepturi': 'http://www.wikidata.org/entity/Q16968451', 'label': 'Zimbabwe', 'description': '2007 live album by Dispatch', 'match': {'type': 'label', 'language': 'en', 'text': 'Zimbabwe'}}, {'id': 'Q106715801', 'title': 'Q106715801', 'pageid': 101988169, 'display': {'label': {'value': 'Zimbabwe', 'language': 'en'}, 'description': {'value': 'episode of Historiepodden published on 3 December 2017 (E182)', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q106715801', 'concepturi': 'http://www.wikidata.org/entity/Q106715801', 'label': 'Zimbabwe', 'description': 'episode of Historiepodden published on 3 December 2017 (E182)', 'match': {'type': 'label', 'language': 'en', 'text': 'Zimbabwe'}}, {'id': 'Q31540781', 'title': 'Q31540781', 'pageid': 33075031, 'display': {'label': {'value': 'Zimbabwe', 'language': 'en'}, 'description': {'value': 'mountain in Zimbabwe', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q31540781', 'concepturi': 'http://www.wikidata.org/entity/Q31540781', 'label': 'Zimbabwe', 'description': 'mountain in Zimbabwe', 'match': {'type': 'label', 'language': 'en', 'text': 'Zimbabwe'}}, {'id': 'Q3575542', 'title': 'Q3575542', 'pageid': 3404112, 'display': {'label': {'value': 'Zimbabwe', 'language': 'en'}, 'description': {'value': '2008 film by Darrell Roodt', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q3575542', 'concepturi': 'http://www.wikidata.org/entity/Q3575542', 'label': 'Zimbabwe', 'description': '2008 film by Darrell Roodt', 'match': {'type': 'label', 'language': 'en', 'text': 'Zimbabwe'}}, {'id': 'Q8071962', 'title': 'Q8071962', 'pageid': 8021357, 'display': {'label': {'value': 'Zimbabwe', 'language': 'en'}, 'description': {'value': '1979 song by Bob Marley', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q8071962', 'concepturi': 'http://www.wikidata.org/entity/Q8071962', 'label': 'Zimbabwe', 'description': '1979 song by Bob Marley', 'match': {'type': 'label', 'language': 'en', 'text': 'Zimbabwe'}}, {'id': 'Q28554175', 'title': 'Q28554175', 'pageid': 30247040, 'display': {'label': {'value': 'Zimbabwe', 'language': 'en'}, 'description': {'value': 'painting by Fred Wilson', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q28554175', 'concepturi': 'http://www.wikidata.org/entity/Q28554175', 'label': 'Zimbabwe', 'description': 'painting by Fred Wilson', 'match': {'type': 'label', 'language': 'en', 'text': 'Zimbabwe'}}], 'search-continue': 7, 'success': 1}

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
example = "Most people in Berlin think that Angela Merkel is the Chancellor of Germany"

ner_results = nlp(example)
print(ner_results)
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'entity': 'B-LOC', 'score': 0.9997603, 'index': 4, 'word': 'Berlin', 'start': 15, 'end': 21}, {'entity': 'B-PER', 'score': 0.9997875, 'index': 7, 'word': 'Angela', 'start': 33, 'end': 39}, {'entity': 'I-PER', 'score': 0.99973124, 'index': 8, 'word': 'Me', 'start': 40, 'end': 42}, {'entity': 'I-PER', 'score': 0.99930453, 'index': 9, 'word': '##rk', 'start': 42, 'end': 44}, {'entity': 'I-PER', 'score': 0.88110745, 'index': 10, 'word': '##el', 'start': 44, 'end': 46}, {'entity': 'B-LOC', 'score': 0.99969304, 'index': 15, 'word': 'Germany', 'start': 68, 'end': 75}]
